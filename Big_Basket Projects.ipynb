# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('BigBasket Products.csv')

# %%
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %%
# Use head function to look for first 12 rows

df.head(12)
# Out:
#     index                                            product  \
# 0       1             Garlic Oil - Vegetarian Capsule 500 mg
# 1       2                              Water Bottle - Orange
# 2       3                     Brass Angle Deep - Plain, No.2
# 3       4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4       5                 Creme Soft Soap - For Hands & Body
# 5       6                  Germ - Removal Multipurpose Wipes
# 6       7                                       Multani Mati
# 7       8                  Hand Sanitizer - 70% Alcohol Base
# 8       9  Biotin & Collagen Volumizing Hair Shampoo + Bi...
# 9      10               Scrub Pad - Anti- Bacterial, Regular
# 10     11                           Wheat Grass Powder - Raw
# 11     12                     Butter Cookies Gold Collection
#
#                   category            sub_category              brand  \
# 0         Beauty & Hygiene               Hair Care  Sri Sri Ayurveda
# ...

# %%
# Get Description of the data in the DataFrame. (Only Include Numeric Columns)

df.describe()
# Out:
#              index     sale_price  market_price        rating
# count  27555.00000   27549.000000  27555.000000  18919.000000
# mean   13778.00000     334.648391    382.056664      3.943295
# std     7954.58767    1202.102113    581.730717      0.739217
# min        1.00000       2.450000      3.000000      1.000000
# 25%     6889.50000      95.000000    100.000000      3.700000
# 50%    13778.00000     190.320000    220.000000      4.100000
# 75%    20666.50000     359.000000    425.000000      4.300000
# max    27555.00000  112475.000000  12500.000000      5.000000

# %%
df.describe().T  # Transposed
# Out:
#                 count          mean          std   min     25%       50%  \
# index         27555.0  13778.000000  7954.587670  1.00  6889.5  13778.00
# sale_price    27549.0    334.648391  1202.102113  2.45    95.0    190.32
# market_price  27555.0    382.056664   581.730717  3.00   100.0    220.00
# rating        18919.0      3.943295     0.739217  1.00     3.7      4.10
#
#                   75%       max
# index         20666.5   27555.0
# sale_price      359.0  112475.0
# market_price    425.0   12500.0
# rating            4.3       5.0

# %%
# Step 4: Find Information about the DataFrame.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27555 entries, 0 to 27554
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         27555 non-null  int64
#  1   product       27554 non-null  object
#  2   category      27555 non-null  object
#  3   sub_category  27555 non-null  object
#  4   brand         27554 non-null  object
#  5   sale_price    27549 non-null  float64
#  6   market_price  27555 non-null  float64
#  7   type          27555 non-null  object
#  8   rating        18919 non-null  float64
#  9   description   27440 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 2.1+ MB

# %%
# Step 5: Find out Top & least sold products.

df['product'].value_counts()
# Out:
# Turmeric Powder/Arisina Pudi                                     26
# Extra Virgin Olive Oil                                           15
# Cow Ghee/Tuppa                                                   14
# Soft Drink                                                       12
# Colorsilk Hair Colour With Keratin                               12
#                                                                  ..
# Pepper & Herb Salami Chicken                                      1
# Nutmeg Powder                                                     1
# Disney Mickey Mouse Plastic Kids Sipper Bottle - Coolest Dude     1
# Chocolates-Roasted Peanut Chocolate                               1
# Green Tea - Pure Original                                         1
# Name: product, Length: 23540, dtype: int64

# %%
# Step 6: Measuring discount on a certain item.

df.insert(7,'Discounts',df.market_price - df.sale_price)

# %%
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %%
# Step 7: Find out the Missing Values from the Dataset.

df.isnull().sum()
# Out:
# index              0
# product            1
# category           0
# sub_category       0
# brand              1
# sale_price         6
# market_price       0
# Discounts          6
# type               0
# rating          8636
# description      115
# dtype: int64

# %%
df.drop('index',axis=1,inplace=True)

# %%
df['product'] = df['product'].fillna('Unknown')
df.brand = df.brand.fillna('Unknown')
df.sale_price = df.sale_price.fillna(df.sale_price.median())
df.rating = df.rating.fillna(df.rating.median())
df.description = df.description.fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# product         0
# category        0
# sub_category    0
# brand           0
# sale_price      0
# market_price    0
# Discounts       6
# type            0
# rating          0
# description     0
# dtype: int64

# %%
# Checking Outliers


sns.boxplot(df.sale_price,orient='h')
# Out:
# <Axes: >

# %%
sns.boxplot(df.sale_price,orient='h')
# Out:
# <Axes: >

# %%
sns.boxplot(df.market_price,orient='h')
# Out:
# <Axes: >

# %%
Q1,Q3 = df.sale_price.quantile([0.25,0.75])

# %%
Q1,Q3
# Out:
# (95.0, 359.0)

# %%
IQR = Q3 - Q1

# %%
IQR
# Out:
# 264.0

# %%
UL = Q3 + 1.5*(IQR)
LL = Q1 - 1.5*(IQR)

# %%
UL,LL
# Out:
# (755.0, -301.0)

# %%
df.sale_price.max()
# Out:
# 112475.0

# %%
df.market_price.max()
# Out:
# 12500.0

# %%
df[df.sale_price==112475.0]
# Out:
#         product          category    sub_category       brand  sale_price  \
# 1249  Beard Kit  Beauty & Hygiene  Men's Grooming  Uncle Tony    112475.0
#
#       market_price  Discounts                type  rating  \
# 1249        3300.0  -109175.0  Combos & Gift Sets     4.1
#
#                                             description
# 1249  The combination of a beard oil, a beard wash, ...

# %%
df[df.sale_price>20000]
# Out:
#                                                 product  \
# 248   4mm Aluminium Induction Base Chapati Roti Tawa...
# 288           Arrabbiata Tomato Pasta Sauce With Chilli
# 436                        Balloon - Polka Dot, 12 Inch
# 1249                                          Beard Kit
#
#                     category            sub_category       brand  sale_price  \
# 248   Kitchen, Garden & Pets    Cookware & Non Stick       HAZEL    111649.0
# 288     Gourmet & World Food  Sauces, Spreads & Dips   Montanini     22325.0
# 436     Cleaning & Household   Party & Festive Needs    B Vishal     88899.0
# 1249        Beauty & Hygiene          Men's Grooming  Uncle Tony    112475.0
#
#       market_price  Discounts                      type  rating  \
# 248         1289.0  -110360.0          Tawa & Sauce Pan     4.1
# 288          325.0   -22000.0   Mustard & Cheese Sauces     5.0
# 436          129.0   -88770.0  Caps, Balloons & Candles     3.9
# ...

# %%
df[df.sale_price>10000]
# Out:
#                                                  product  \
# 248    4mm Aluminium Induction Base Chapati Roti Tawa...
# 288            Arrabbiata Tomato Pasta Sauce With Chilli
# 436                         Balloon - Polka Dot, 12 Inch
# 1249                                           Beard Kit
# 21761      Pet Food - N&D Team Breeder Puppy Top Farmina
# 25301                                    Bravura Clipper
#
#                      category            sub_category       brand  sale_price  \
# 248    Kitchen, Garden & Pets    Cookware & Non Stick       HAZEL    111649.0
# 288      Gourmet & World Food  Sauces, Spreads & Dips   Montanini     22325.0
# 436      Cleaning & Household   Party & Festive Needs    B Vishal     88899.0
# 1249         Beauty & Hygiene          Men's Grooming  Uncle Tony    112475.0
# 21761  Kitchen, Garden & Pets  Pet Food & Accessories     Farmina     10090.0
# 25301  Kitchen, Garden & Pets  Pet Food & Accessories        Wahl     12500.0
#
# ...

# %%
# Make those values that is more than 20000 in sale price to null
# and fill them with the market price

# %%
df.sale_price = np.where(df.sale_price>20000,np.nan,df.sale_price)

# %%
df[df.sale_price==df.sale_price.max()]
# Out:
#                product                category            sub_category brand  \
# 25301  Bravura Clipper  Kitchen, Garden & Pets  Pet Food & Accessories  Wahl
#
#        sale_price  market_price  Discounts                     type  rating  \
# 25301     12500.0       12500.0        0.0  Pet Cleaning & Grooming     4.1
#
#                                              description
# 25301  The bravura clipper is a must-have clipper for...

# %%
df.isnull().sum()
# Out:
# product         0
# category        0
# sub_category    0
# brand           0
# sale_price      4
# market_price    0
# Discounts       6
# type            0
# rating          0
# description     0
# dtype: int64

# %%
df.sale_price.isnull().index
# Out:
# RangeIndex(start=0, stop=27555, step=1)

# %%
df.sale_price.isna().index
# Out:
# RangeIndex(start=0, stop=27555, step=1)

# %%
df[df.sale_price.isnull()]
# Out:
#                                                 product  \
# 248   4mm Aluminium Induction Base Chapati Roti Tawa...
# 288           Arrabbiata Tomato Pasta Sauce With Chilli
# 436                        Balloon - Polka Dot, 12 Inch
# 1249                                          Beard Kit
#
#                     category            sub_category       brand  sale_price  \
# 248   Kitchen, Garden & Pets    Cookware & Non Stick       HAZEL         NaN
# 288     Gourmet & World Food  Sauces, Spreads & Dips   Montanini         NaN
# 436     Cleaning & Household   Party & Festive Needs    B Vishal         NaN
# 1249        Beauty & Hygiene          Men's Grooming  Uncle Tony         NaN
#
#       market_price  Discounts                      type  rating  \
# 248         1289.0  -110360.0          Tawa & Sauce Pan     4.1
# 288          325.0   -22000.0   Mustard & Cheese Sauces     5.0
# 436          129.0   -88770.0  Caps, Balloons & Candles     3.9
# ...

# %%
df.sale_price = df.sale_price.fillna(df.market_price)

# %%
df[248:249]
# Out:
#                                                product  \
# 248  4mm Aluminium Induction Base Chapati Roti Tawa...
#
#                    category          sub_category  brand  sale_price  \
# 248  Kitchen, Garden & Pets  Cookware & Non Stick  HAZEL      1289.0
#
#      market_price  Discounts              type  rating  \
# 248        1289.0  -110360.0  Tawa & Sauce Pan     4.1
#
#                                            description
# 248  Hazel Aluminium Tawa has an ergonomic design f...

# %%
df[288:289]
# Out:
#                                        product              category  \
# 288  Arrabbiata Tomato Pasta Sauce With Chilli  Gourmet & World Food
#
#                sub_category      brand  sale_price  market_price  Discounts  \
# 288  Sauces, Spreads & Dips  Montanini       325.0         325.0   -22000.0
#
#                         type  rating description
# 288  Mustard & Cheese Sauces     5.0     Unknown
